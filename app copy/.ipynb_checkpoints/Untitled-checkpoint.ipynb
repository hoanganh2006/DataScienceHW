# %%
import numpy as np 
import pandas as pd
import os
print(os.listdir("../input"))
# Out:
# ['X.npy', 'Y.npy']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
#loading data set
X = np.load('../input/X.npy')
Y = np.load('../input/Y.npy')
print(X.shape, Y.shape)
# Out:
# (2062, 64, 64) (2062, 10)

# %%
import numpy as np

img_array = np.load('../input/X.npy')
img_array
from matplotlib import pyplot as plt

for x in range(50,60):
   
   plt.imshow(img_array[x], cmap = 'gray')
   plt.show()
#     print(img_array[x])
